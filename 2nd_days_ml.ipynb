# %% [markdown]
# <a href="https://colab.research.google.com/github/Prashantgauraw/day_2nd_machine_learning/blob/main/2nd_days_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ML steps**
#
# 1. Importing the library
# 2. upload the data
# 3. data prepration
# 4. splitin the data
# 5. Model creation
# 6. Model Traning
# 7. Predicting the model
#
# **Linear Regression Example**
#
# **Maths behind**
#
# y = mx + b (Where b is the intercept and m is the slope of the line.)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-96dd290c-3fdf-4c75-8068-ca6dd3465165" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96dd290c-3fdf-4c75-8068-ca6dd3465165">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
#loading the data
df = pd.read_csv("student_scores.csv")
print(df.head())
#ploting the data
df.plot(x='Hours', y='Scores', style='o')
plt.title('houres study vs scores')
plt.xlabel('houres')
plt.ylabel('score')
plt.show()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# ## **Preparing the Data**

# %%
import pandas as pd
df = pd.read_csv('student_scores.csv')
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

print(x)
print(y)
# Out:
# [[2.5]
#  [5.1]
#  [3.2]
#  [8.5]
#  [3.5]
#  [1.5]
#  [9.2]
#  [5.5]
#  [8.3]
#  [2.7]
#  [7.7]
#  [5.9]
#  [4.5]
#  [3.3]
#  [1.1]
#  [8.9]
#  [2.5]
#  [1.9]
#  [6.1]
#  [7.4]
#  [2.7]
#  [4.8]
#  [3.8]
#  [6.9]
#  [7.8]]
# [21 47 27 75 30 20 88 60 81 25 85 62 41 42 17 95 30 24 67 69 30 54 35 76
#  86]

# %% [markdown]
# **Splitting the data** (usin train test split)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv('student_scores.csv')
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

x_tarin,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)
print("train data is 70% and test data is 30%")
print("x_tarin")
print(x_tarin)

print("x_test")
print(x_test,'\n')

print("y_train")
print(y_train)
print("y_test")
print(y_test)
# Out:
# train data is 70% and test data is 30%
# x_tarin
# [[6.9]
#  [1.1]
#  [5.1]
#  [7.7]
#  [3.3]
#  [8.3]
#  [9.2]
#  [6.1]
#  [3.5]
#  [2.7]
#  [5.5]
#  [2.7]
#  [8.5]
#  [2.5]
#  [4.8]
#  [8.9]
#  [4.5]]
# x_test
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]
#  [3.8]
#  [1.9]
#  [7.8]]
#
# y_train
# [76 17 47 85 42 81 88 67 30 25 60 30 75 21 54 95 41]
# y_test
# [20 27 69 30 62 35 24 86]

# %% [markdown]
# **Craeting Model &
# Training the Model &
# Predicting the Model**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df = pd.read_csv('student_scores.csv')
x= df.iloc[:,:-1].values
y=df.iloc[:,-1].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)
#Craeting model
Lr=LinearRegression()

#Training the model
Lr.fit(x_train,y_train)

#Predicting the model
# print(Lr.predict([[6.9]]))

y_pred = Lr.predict(x_test)
print(y_pred)
# Out:
# [17.05366541 33.69422878 74.80620886 26.8422321  60.12335883 39.56736879
#  20.96909209 78.72163554]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df= pd.read_csv('student_scores.csv')

x = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state = 0)

Lr=LinearRegression()

Lr.fit(x_train,y_train)

y_pred = Lr.predict(x_test)
d = {'Actual': y_test, 'Predicted': y_pred}
compare_df = pd.DataFrame(d)
print(compare_df)

print()
#checking the intercept
print('intercept :',Lr.intercept_)

#Getting coefficient from created model
print('coefficient :',Lr.coef_)
# Out:
#    Actual  Predicted
# 0      20  17.053665
# 1      27  33.694229
# 2      69  74.806209
# 3      30  26.842232
# 4      62  60.123359
# 5      35  39.567369
# 6      24  20.969092
# 7      86  78.721636
#
# intercept : 2.3708153823418883
# coefficient : [9.78856669]

# %% [markdown]
# **Evaluation metrics**
#
#
#
# 1. Mean Absolute Error (MAE)
# 2. Mean Squared Error (MSE)
# 3. Root Mean Squared Error (RMSE)

# %%
#importin the library
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

#import the dataset
df = pd.read_csv('student_scores.csv')

#data prepration
X = df.iloc[:, :-1].values
y = df.iloc[:, 1].values

#spliting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

#model creation
Lr = LinearRegression()

#traning the model
Lr.fit(X_train, y_train)

#predicting the model
y_pred = Lr.predict(X_test)
print(y_pred)

#evaluation metrics
print()
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Mean Absolute Error:', mae)
print('Mean Squared Error:', mse)
print('Root Mean Squared Error:', rmse)
# Out:
# [16.88414476 33.73226078 75.357018   26.79480124 60.49103328]
#
# Mean Absolute Error: 4.183859899002982
# Mean Squared Error: 21.598769307217456
# Root Mean Squared Error: 4.647447612100373
